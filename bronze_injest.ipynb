# %%
# %python
from pyspark.sql.functions import col, lit, current_timestamp, when

# ------------------------------
# Step 1: Check if Bronze table exists
# ------------------------------
try:
    bronze_df = spark.table("workspace.inflation.daily_prices")
    print("✅ Bronze table loaded successfully!")
except Exception as e:
    raise Exception(
        "Bronze table does not exist. Please run the Price Generator notebook first."
    ) from e

# ------------------------------
# Step 2: Minimal Bronze Processing (optional)
# ------------------------------
bronze_df = bronze_df.withColumn("ingested_at", current_timestamp())

# ------------------------------
# Step 3: Save processed Bronze table (overwrite)
# ------------------------------
bronze_df.write.format("delta").mode("overwrite").saveAsTable(
    "workspace.inflation.bronze_daily_prices_processed"
)

print("✅ Bronze table injected successfully and ready for Silver processing!")

# ------------------------------
# Step 4: Preview Bronze Table
# ------------------------------
display(
    bronze_df.orderBy(
        "date",
        "item_id"
    )
)
